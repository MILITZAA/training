# %% [markdown]
# # 1 Add Data Sources
#
# * go https://lookerstudio.google.com/overview
#
# ![image.png](attachment:image.png)
#
# # 2 Create Blended Data
#
# ![image-2.png](attachment:image-2.png)
#
# Combina las tablas bikeshare_stations y bikeshare_trips del conjunto de datos Austin Bikeshare.
# Tipo de unión: Utiliza una unión interna (inner join) en el campo station_id para combinar los datos entre los viajes y las estaciones.
# Ejemplo: Calcula el número de viajes por estación y combina esto con datos de la estación, como la ubicación (latitud, longitud).
# Utiliza estos datos combinados para crear visualizaciones, tales como:
# Un gráfico de barras que muestre el número de viajes por estación.
# Un mapa que muestre las ubicaciones de las estaciones y el número de viajes que se originan en cada estación.
#
# # 3 Create Calculated Fielda
#
# Crea campos calculados basados en el conjunto de datos de Precios de Viviendas de Kaggle.
# Tarea:
# Ejemplos de campos calculados:
# Precio por pie cuadrado: Crea un campo calculado que divida el SalePrice (Precio de Venta) por el GrLivArea (Área habitable sobre el nivel del suelo).
# Estimación de la hipoteca mensual: Utiliza una tasa de interés y un plazo de préstamo fijos para estimar los pagos mensuales de la hipoteca basándote en el SalePrice (Precio de Venta).
#
# ![image-3.png](attachment:image-3.png)
#
# # 4 Create Metrics
#
# Define métricas clave utilizando el conjunto de datos de Precios de Viviendas de Kaggle.
# Tarea:
# Crea métricas tales como:
# Precio promedio de la vivienda: Calcula el valor promedio de SalePrice (Precio de Venta).
# Número total de viviendas vendidas: Cuenta el número total de entradas en el conjunto de datos.
# Área habitable promedio: Calcula el promedio de GrLivArea (Área habitable sobre el nivel del suelo).
#
# # 5 Customize the Dashboards Canvas and Navigation
#
# Organiza gráficos, tablas y elementos visuales en el panel de control para mayor claridad.
# Agrega botones de navegación o filtros para cambiar entre vistas (por ejemplo, por vecindario, estilo de vivienda).
#
# # 6 Use Custom Filters
#
# Aplica filtros personalizados al conjunto de datos de Precios de Viviendas de Kaggle y a los datos combinados de Austin Bikeshare.
# Tarea:
# Agrega filtros tales como:
# Rango de precios: Permite a los usuarios filtrar por el precio de la vivienda (SalePrice).
# Rango de área habitable: Filtra las viviendas por GrLivArea (área habitable sobre el nivel del suelo).
# Nombre de la estación: Filtra por estación de los datos de Austin Bikeshare.
# Duración del viaje: Filtra los viajes de bicicletas compartidas por duración (duration_minutes).
#
# # 7 Use Parameters for Data
#
# Utiliza parámetros en Looker para controlar los datos de forma dinámica.
# Tarea:
# Crea parámetros para:
# Seleccionar un rango de tiempo (por ejemplo, filtrar viviendas vendidas dentro de un período determinado o viajes de bicicletas compartidas dentro de un rango de fechas).
# Elegir una fuente de datos (por ejemplo, alternar entre el conjunto de datos de viviendas y los datos de bicicletas compartidas).
#
# # 8 Add Charts, Tables, and Configure Dimensions and Appearance
#
# Add visual elements such as charts and tables to present the data.
# Task:
# Add visualizations such as:
# Bar chart: Show the average home prices by Neighborhood from the Kaggle dataset.
# Line chart: Display the number of bikeshare trips over time in Austin.
# Table: List properties with their price, square footage, and the estimated monthly mortgage.
# Configure dimensions, filters, and appearance to enhance readability and visual appeal.
#
# # 9 Manage Permissions for sharing Dashboards and Settings Roles
#
# Configura permisos para compartir el panel de control y asignar roles.
# Tarea:
# Comparte el panel de control con usuarios o grupos específicos (por ejemplo, miembros del equipo).
# Asigna roles como Visor o Editor para controlar lo que los usuarios pueden ver y modificar.
